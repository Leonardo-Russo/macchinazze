# %%
# from model import *
from utils import getImage

# # Path to the checkpoint file
# checkpoint_path = r'lightning_logs\medium_training\version_0\epoch=13-val_loss=0.77.ckpt'

# # Load the model from the checkpoint
# model = MLP.load_from_checkpoint(checkpoint_path)
# print(model)

# sample = getImage(debug=True, kappa=0)

# NOTE: aumentare i valori di focal_length e sensor_size rende meno problematica la presenza di kappa, anche se rimangono artefatti nella world_grid
sample = getImage(focal_length=0.036, sensor_size=(0.0367, 0.0274), debug=True, kappa=0.0)
# Out:
# world_scale_factor:  1.32
# 3d_center:  [-22.337682776824458, 10.00811279939866, 0, 1]
# zc:  [-0.66086219  0.73321622 -0.1601722 ]
# b_hat:  [-0.79570792  0.60114001 -0.07402431]
# image_box:  [[205.79034358 200.2284409 ]
#  [242.63378541 196.87541031]
#  [242.21167711 175.43528648]
#  [205.13172778 177.58651602]
#  [156.77502122 195.04341597]
#  [193.13573918 192.21054629]
#  [192.49837686 172.44462414]
#  [155.91216919 174.2604813 ]]
# image_center:  [[199.02984071 195.9450198 ]]
# samples_counter:  1
