# %%
# from model import *
from utils import getImage

# # Path to the checkpoint file
# checkpoint_path = r'lightning_logs\medium_training\version_0\epoch=13-val_loss=0.77.ckpt'

# # Load the model from the checkpoint
# model = MLP.load_from_checkpoint(checkpoint_path)
# print(model)

# sample = getImage(debug=True, kappa=0)

# NOTE: aumentare i valori di focal_length e sensor_size rende meno problematica la presenza di kappa, anche se rimangono artefatti nella world_grid
sample = getImage(focal_length=0.03458, sensor_size=(0.03941, 0.022), debug=True, kappa=0.0)
# Out:
# world_scale_factor:  1.32
# 3d_center:  [8.402278680383127, -1.817753831027602, 0, 1]
# zc:  [-0.69472806 -0.70259391 -0.15399583]
# b_hat:  [-0.4948913  -0.85606668 -0.14910549]
# image_box:  [[103.43736208 262.47094608]
#  [140.28337833 277.41122036]
#  [138.35903867 225.97759982]
#  [101.34416344 215.89848145]
#  [208.03391569 243.95840565]
#  [249.11323999 255.05375189]
#  [248.46469629 210.90235551]
#  [207.09594271 203.43820988]]
# image_center:  [[178.25641784 258.66147897]]
# samples_counter:  1
